# %% [markdown]
# # Loading data

# %%
import warnings
warnings.filterwarnings('ignore')
from tensorboard.plugins.hparams import api as hp

# Dataset hyper parameters
HP_BALANCED = hp.HParam('balanced', hp.Discrete([0, 1])) # 0 unbalanced, 1 balanced
HP_NORM_IMAGES = hp.HParam('norm_images', hp.Discrete([0, 1]))

HP_NETWORKS = hp.HParam('network', hp.Discrete(['CNN'
                                               ])) 


HP_ACTIVATION_FUNCTIONS = hp.HParam('act_functions', hp.Discrete(['relu', 'selu', 'tanh']))
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([16, 32, 64, 128]))
HP_EARLY_STOP = hp.HParam('early_stop', hp.Discrete([3, 5, 7, 10]))
HP_DROPOUT = hp.HParam('dropout', hp.RealInterval(0.2, 0.5))
HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'sgd']))
# Out:
# 2022-10-29 23:24:52.293276: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-29 23:24:52.449538: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-10-29 23:24:52.476335: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-29 23:24:53.093425: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib/cuda/include:/usr/lib/cuda/lib64:
# 2022-10-29 23:24:53.093481: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib/cuda/include:/usr/lib/cuda/lib64:
# 2022-10-29 23:24:53.093485: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
import tensorflow as tf
import numpy as np

np.random.seed(42)
tf.random.set_seed(42)


def run(run_dir, hparams):
    with tf.summary.create_file_writer(run_dir).as_default():
        hp.hparams(hparams)
        result_metrics = train_test_model(hparams)
        tf.summary.scalar(METRIC_NAMES, result_metrics, step=1)

# %%
from tensorflow.keras import datasets, layers, models

# Function for normalizing images
def normImages(X):
    for i, image in enumerate(X):
        max_n = np.max(image)
        image /= max_n
        X[i] = np.abs(image)
    return X

# Obtaining training, validation and test data
def train_val_test_split(balanced, normalized):
    spectrogram = ['spectrogram', 'mel', 'mtf']
    # spectrogram = ['spectrogram', 'spectrogram', 'spectrogram']
    
    X_train = []
    X_test = []
    X_val = []

    y_flag = 0 # y's has not been obtained yet 
    # root_dir = "/home/polivares/scratch/Datasets/PowerLineFaults/"
    root_dir = '/home/polivares/Dropbox/Work/PostDoc/PowerLineFaults/'
    
    for sp in spectrogram:
        X_full = np.load(f"{root_dir}dataset_{sp}/full/images_full.npy")
        
        
        if not y_flag:
            y_flag = 1
            
            y_full = np.load(f"{root_dir}dataset_{sp}/full/labels_full.npy").reshape(-1)
            if balanced: # getting balanced data from index
                # Index 1, partial discharge
                index_1 = np.where(y_full==1)[0]
                len_index_1 = len(index_1)
                index_train_1, index_val_1, index_test_1 = index_1[:len_index_1//3], index_1[len_index_1//3:2*len_index_1//3], index_1[2*len_index_1//3:4*len_index_1//3]

                # Index 0, non partial discharge
                index_0 = np.where(y_full==0)[0]
                index_train_0, index_val_0, index_test_0 = index_0[:len_index_1//3], index_0[len_index_1//3:2*len_index_1//3], index_0[2*len_index_1//3:4*len_index_1//3]

                # Obtaining index
                index_train = np.concatenate([index_train_0, index_train_1])
                np.random.shuffle(index_train)
                index_val = np.concatenate([index_val_0, index_val_1])
                np.random.shuffle(index_val)
                index_test = np.concatenate([index_test_0, index_test_1])
                np.random.shuffle(index_test)

            else: # Unbalanced data, similar to the original from index
                index_full = np.arange(len(y_full))
                np.random.shuffle(index_full)
                len_index = 1000
                
                # Obtaining index
                index_train, index_val, index_test = index_full[:len_index], index_full[len_index:2*len_index], index_full[2*len_index:]
            
            y_train = y_full[index_train]
            y_val = y_full[index_val]
            y_test = y_full[index_test]
            
            del y_full
        
        if normalized:
            X_full = normImages(X_full)
        
        X_train.append(X_full[index_train])
        X_val.append(X_full[index_val])
        X_test.append(X_full[index_test])
        
        del X_full
        
    X_train_c = np.concatenate(X_train, axis=3) 
    X_val_c = np.concatenate(X_val, axis=3)
    X_test_c = np.concatenate(X_test, axis=3)
    
    return X_train_c, y_train, X_val_c, y_val, X_test_c, y_test


# X_train_c, y_train, X_val_c, y_val, X_test_c, y_test = train_val_test_split(balanced=0,normalized=0)

# %%
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import matthews_corrcoef 

def train_test_model(hparams, METRICS, data):
    # Data
    X_train, y_train, X_val, y_val, X_test, y_test = data
    
    # Model creation
    print("Model creation")
    
    model = tf.keras.models.Sequential()
    model.add(layers.Conv2D(32, (5, 5), input_shape=(256, 256, 3), activation=hparams[HP_ACTIVATION_FUNCTIONS]))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(64, 3, padding='same', activation=hparams[HP_ACTIVATION_FUNCTIONS]))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(128, 3, padding='same', activation=hparams[HP_ACTIVATION_FUNCTIONS]))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(256, activation=hparams[HP_ACTIVATION_FUNCTIONS]))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Dropout(hparams[HP_DROPOUT]))
    model.add(layers.Dense(1, activation='sigmoid'))
    
    # model = models.Sequential()
    # model.add(layers.Conv2D(32, (5, 5), input_shape=(256, 256, 3), activation=hparams[HP_ACTIVATION_FUNCTIONS]))
    # model.add(layers.MaxPooling2D(pool_size=(2, 2)))
    # model.add(layers.Dropout(hparams[HP_DROPOUT]))
    # model.add(layers.Conv2D(64, (5, 5), activation=hparams[HP_ACTIVATION_FUNCTIONS]))
    # model.add(layers.MaxPooling2D(pool_size=(2, 2)))
    # model.add(layers.Dropout(hparams[HP_DROPOUT]))
    # model.add(layers.Flatten())
    # model.add(layers.Dense(128, activation=hparams[HP_ACTIVATION_FUNCTIONS]))
    # model.add(layers.Dropout(hparams[HP_DROPOUT]))
    # model.add(layers.Dense(1, activation='sigmoid'))
    
    # Compile model
    print("Model compile")
    early_stopping = EarlyStopping(patience = hparams[HP_EARLY_STOP])
    model.compile(loss = 'bce', optimizer = hparams[HP_OPTIMIZER], metrics=METRICS)
    
    # Obtaining data 
    # print("Obtaining data")
    # X_train, y_train, X_val, y_val, X_test, y_test = train_val_test_split(hparams[HP_BALANCED], hparams[HP_NORM_IMAGES])
    
    # Fitting training
    print("Fitting training")
    history_model = model.fit(X_train, y_train, epochs=1000, 
                            validation_data=(X_val, y_val),
                            batch_size=10,
                            callbacks=[early_stopping])
    # Evaluation on test
    print("Evaluation on test")
    results = model.evaluate(X_test, y_test)
    
    y_pred = (model.predict(X_test, batch_size=4)>0.5).reshape(1,-1)[0].astype(int)
    
    
    results.append(matthews_corrcoef(y_test, y_pred))
    
    del model, y_pred
    # Returning metrics results
    print("Returning metrics results")
    return results

# %%
# Run evaluation with hparams
def run(run_dir, hparams, data):
    METRICS = [
          tf.keras.metrics.TruePositives(name='tp'),
          tf.keras.metrics.FalsePositives(name='fp'),
          tf.keras.metrics.TrueNegatives(name='tn'),
          tf.keras.metrics.FalseNegatives(name='fn'), 
          tf.keras.metrics.BinaryAccuracy(name='accuracy'),
          tf.keras.metrics.Precision(name='precision'),
          tf.keras.metrics.Recall(name='recall'),
          tf.keras.metrics.AUC(name='auc'),
          tf.keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
    ]
    
    METRICS_NAMES = [
        'loss',
        'tp',
        'fp',
        'tn',
        'fn',
        'accuracy',
        'precision',
        'recall',
        'auc',
        'prc',
        'mcc'
    ]

    with tf.summary.create_file_writer(run_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        results = train_test_model(hparams, METRICS, data)
        print("Tipo results", type(results))
    
        for name, metric in zip(METRICS_NAMES, results):
            print(f"Summary: metric {name} value {metric}")
            tf.summary.scalar(name, metric, step=1)

# %%
session_num = 0

print("Obtaining data")
# data = train_val_test_split(hparams[HP_BALANCED], hparams[HP_NORM_IMAGES])
data = train_val_test_split(1, 1)
# data = train_val_test_split(1, 0)
# data = train_val_test_split(0, 1)
# data = train_val_test_split(0, 0)

# for balanced in HP_BALANCED.domain.values:
#     for norm_image in HP_NORM_IMAGES.domain.values:

for act_func in HP_ACTIVATION_FUNCTIONS.domain.values:
    for num_units in HP_NUM_UNITS.domain.values:
        for dropout in (HP_DROPOUT.domain.min_value, HP_DROPOUT.domain.max_value):
            for early_stop in HP_EARLY_STOP.domain.values:
                for optimizer in HP_OPTIMIZER.domain.values:
                    tf.keras.backend.clear_session()
                    hparams = {
                         HP_BALANCED : 1,
                         HP_NORM_IMAGES: 1,
                         HP_NETWORKS: 'CNN',
                         HP_ACTIVATION_FUNCTIONS: act_func,
                         HP_NUM_UNITS: num_units,
                         HP_DROPOUT: dropout,
                         HP_EARLY_STOP: early_stop,
                         HP_OPTIMIZER: optimizer
                    }
                    run_name = "run-%d" % session_num
                    print('--- Starting trial: %s' % run_name)
                    print({h.name: hparams[h] for h in hparams})
                    run('logs/hparam_tuning/' + run_name, hparams, data)
                    session_num += 1
# Out:
# Obtaining data
# --- Starting trial: run-0
# {'balanced': 1, 'norm_images': 1, 'network': 'CNN', 'act_functions': 'relu', 'num_units': 16, 'dropout': 0.2, 'early_stop': 3, 'optimizer': 'adam'}
# Model creation
# Model compile
# Fitting training
# 2022-10-29 23:25:02.871041: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-29 23:25:02.921529: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-29 23:25:02.921654: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-29 23:25:02.922130: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-29 23:25:02.923474: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-29 23:25:02.923632: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-29 23:25:02.923713: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-29 23:25:03.316201: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-29 23:25:03.316350: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-29 23:25:03.316442: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-29 23:25:03.316531: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4117 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Epoch 1/1000
# 2022-10-29 23:25:05.235557: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8300
# 2022-10-29 23:25:06.369445: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 35/35 [==============================] - 5s 56ms/step - loss: 0.7900 - tp: 118.0000 - fp: 55.0000 - tn: 120.0000 - fn: 57.0000 - accuracy: 0.6800 - precision: 0.6821 - recall: 0.6743 - auc: 0.7356 - prc: 0.6892 - val_loss: 0.7404 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.6858 - val_prc: 0.6700
# Epoch 2/1000
# 35/35 [==============================] - 1s 43ms/step - loss: 0.4445 - tp: 135.0000 - fp: 36.0000 - tn: 139.0000 - fn: 40.0000 - accuracy: 0.7829 - precision: 0.7895 - recall: 0.7714 - auc: 0.8789 - prc: 0.8798 - val_loss: 0.7828 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.6413 - val_prc: 0.6567
# Epoch 3/1000
# 35/35 [==============================] - 1s 43ms/step - loss: 0.3803 - tp: 137.0000 - fp: 35.0000 - tn: 140.0000 - fn: 38.0000 - accuracy: 0.7914 - precision: 0.7965 - recall: 0.7829 - auc: 0.9057 - prc: 0.9137 - val_loss: 0.6867 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.7156 - val_prc: 0.7262
# Epoch 4/1000
# 35/35 [==============================] - 2s 43ms/step - loss: 0.2834 - tp: 153.0000 - fp: 24.0000 - tn: 151.0000 - fn: 22.0000 - accuracy: 0.8686 - precision: 0.8644 - recall: 0.8743 - auc: 0.9501 - prc: 0.9498 - val_loss: 0.9187 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.7076 - val_prc: 0.7005
# Epoch 5/1000
# 35/35 [==============================] - 2s 43ms/step - loss: 0.2544 - tp: 157.0000 - fp: 15.0000 - tn: 160.0000 - fn: 18.0000 - accuracy: 0.9057 - precision: 0.9128 - recall: 0.8971 - auc: 0.9610 - prc: 0.9622 - val_loss: 1.2682 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.6416 - val_prc: 0.6548
# Epoch 6/1000
# 35/35 [==============================] - 2s 43ms/step - loss: 0.1600 - tp: 165.0000 - fp: 9.0000 - tn: 166.0000 - fn: 10.0000 - accuracy: 0.9457 - precision: 0.9483 - recall: 0.9429 - auc: 0.9837 - prc: 0.9876 - val_loss: 1.7678 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.6398 - val_prc: 0.6639
# Evaluation on test
# 17/17 [==============================] - 1s 28ms/step - loss: 2.3373 - tp: 175.0000 - fp: 350.0000 - tn: 0.0000e+00 - fn: 0.0000e+00 - accuracy: 0.3333 - precision: 0.3333 - recall: 1.0000 - auc: 0.6618 - prc: 0.5516
# 132/132 [==============================] - 1s 4ms/step
# Returning metrics results
# Tipo results <class 'list'>
# Summary: metric loss value 2.3372602462768555
# Summary: metric tp value 175.0
# Summary: metric fp value 350.0
# Summary: metric tn value 0.0
# Summary: metric fn value 0.0
# Summary: metric accuracy value 0.3333333432674408
# Summary: metric precision value 0.3333333432674408
# Summary: metric recall value 1.0
# Summary: metric auc value 0.6617550849914551
# Summary: metric prc value 0.5516407489776611
# Summary: metric mcc value 0.0
# --- Starting trial: run-1
# {'balanced': 1, 'norm_images': 1, 'network': 'CNN', 'act_functions': 'relu', 'num_units': 16, 'dropout': 0.2, 'early_stop': 3, 'optimizer': 'sgd'}
# Model creation
# Model compile
# Fitting training
# Epoch 1/1000
# 35/35 [==============================] - 3s 53ms/step - loss: 0.8191 - tp: 121.0000 - fp: 61.0000 - tn: 114.0000 - fn: 54.0000 - accuracy: 0.6714 - precision: 0.6648 - recall: 0.6914 - auc: 0.7318 - prc: 0.7111 - val_loss: 0.8386 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.6266 - val_prc: 0.5926
# Epoch 2/1000
# 35/35 [==============================] - 1s 41ms/step - loss: 0.4903 - tp: 132.0000 - fp: 40.0000 - tn: 135.0000 - fn: 43.0000 - accuracy: 0.7629 - precision: 0.7674 - recall: 0.7543 - auc: 0.8529 - prc: 0.8633 - val_loss: 0.8199 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.4865 - val_prc: 0.4971
# Epoch 3/1000
# 35/35 [==============================] - 1s 42ms/step - loss: 0.3774 - tp: 144.0000 - fp: 35.0000 - tn: 140.0000 - fn: 31.0000 - accuracy: 0.8114 - precision: 0.8045 - recall: 0.8229 - auc: 0.9098 - prc: 0.9119 - val_loss: 0.9764 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.4850 - val_prc: 0.5086
# Epoch 4/1000
# 35/35 [==============================] - 1s 42ms/step - loss: 0.2449 - tp: 157.0000 - fp: 13.0000 - tn: 162.0000 - fn: 18.0000 - accuracy: 0.9114 - precision: 0.9235 - recall: 0.8971 - auc: 0.9651 - prc: 0.9692 - val_loss: 1.2232 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5004 - val_prc: 0.5431
# Epoch 5/1000
# 35/35 [==============================] - 1s 41ms/step - loss: 0.2398 - tp: 159.0000 - fp: 18.0000 - tn: 157.0000 - fn: 16.0000 - accuracy: 0.9029 - precision: 0.8983 - recall: 0.9086 - auc: 0.9662 - prc: 0.9633 - val_loss: 1.4915 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5873 - val_prc: 0.6409
# Evaluation on test
# 17/17 [==============================] - 1s 19ms/step - loss: 1.9631 - tp: 175.0000 - fp: 350.0000 - tn: 0.0000e+00 - fn: 0.0000e+00 - accuracy: 0.3333 - precision: 0.3333 - recall: 1.0000 - auc: 0.6157 - prc: 0.4940
# 132/132 [==============================] - 1s 4ms/step
# Returning metrics results
# Tipo results <class 'list'>
# Summary: metric loss value 1.9631154537200928
# Summary: metric tp value 175.0
# Summary: metric fp value 350.0
# Summary: metric tn value 0.0
# Summary: metric fn value 0.0
# Summary: metric accuracy value 0.3333333432674408
# Summary: metric precision value 0.3333333432674408
# Summary: metric recall value 1.0
# Summary: metric auc value 0.6157224178314209
# Summary: metric prc value 0.4940030872821808
# Summary: metric mcc value 0.0
# --- Starting trial: run-2
# {'balanced': 1, 'norm_images': 1, 'network': 'CNN', 'act_functions': 'relu', 'num_units': 16, 'dropout': 0.2, 'early_stop': 5, 'optimizer': 'adam'}
# Model creation
# Model compile
# Fitting training
# Epoch 1/1000
# 35/35 [==============================] - 3s 55ms/step - loss: 1.0571 - tp: 119.0000 - fp: 64.0000 - tn: 111.0000 - fn: 56.0000 - accuracy: 0.6571 - precision: 0.6503 - recall: 0.6800 - auc: 0.7011 - prc: 0.6735 - val_loss: 0.7136 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 175.0000 - val_fn: 175.0000 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6872 - val_prc: 0.7012
# Epoch 2/1000
# 35/35 [==============================] - 1s 43ms/step - loss: 0.4524 - tp: 131.0000 - fp: 28.0000 - tn: 147.0000 - fn: 44.0000 - accuracy: 0.7943 - precision: 0.8239 - recall: 0.7486 - auc: 0.8828 - prc: 0.8922 - val_loss: 1.6358 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.6750 - val_prc: 0.6388
# Epoch 3/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.3211 - tp: 146.0000 - fp: 22.0000 - tn: 153.0000 - fn: 29.0000 - accuracy: 0.8543 - precision: 0.8690 - recall: 0.8343 - auc: 0.9382 - prc: 0.9421 - val_loss: 1.7745 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.6809 - val_prc: 0.6380
# Epoch 4/1000
# 35/35 [==============================] - 1s 43ms/step - loss: 0.2425 - tp: 160.0000 - fp: 19.0000 - tn: 156.0000 - fn: 15.0000 - accuracy: 0.9029 - precision: 0.8939 - recall: 0.9143 - auc: 0.9637 - prc: 0.9631 - val_loss: 1.1259 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.7565 - val_prc: 0.7380
# Epoch 5/1000
# 35/35 [==============================] - 2s 43ms/step - loss: 0.2153 - tp: 161.0000 - fp: 17.0000 - tn: 158.0000 - fn: 14.0000 - accuracy: 0.9114 - precision: 0.9045 - recall: 0.9200 - auc: 0.9726 - prc: 0.9716 - val_loss: 2.2528 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.6547 - val_prc: 0.6222
# Epoch 6/1000
# 35/35 [==============================] - 2s 43ms/step - loss: 0.2239 - tp: 157.0000 - fp: 11.0000 - tn: 164.0000 - fn: 18.0000 - accuracy: 0.9171 - precision: 0.9345 - recall: 0.8971 - auc: 0.9691 - prc: 0.9721 - val_loss: 1.9083 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.7064 - val_prc: 0.7105
# Evaluation on test
# 17/17 [==============================] - 1s 19ms/step - loss: 2.5308 - tp: 175.0000 - fp: 350.0000 - tn: 0.0000e+00 - fn: 0.0000e+00 - accuracy: 0.3333 - precision: 0.3333 - recall: 1.0000 - auc: 0.7143 - prc: 0.5933
# 132/132 [==============================] - 1s 3ms/step
# Returning metrics results
# Tipo results <class 'list'>
# Summary: metric loss value 2.5308380126953125
# Summary: metric tp value 175.0
# Summary: metric fp value 350.0
# Summary: metric tn value 0.0
# Summary: metric fn value 0.0
# Summary: metric accuracy value 0.3333333432674408
# Summary: metric precision value 0.3333333432674408
# Summary: metric recall value 1.0
# Summary: metric auc value 0.7143101692199707
# Summary: metric prc value 0.5932965278625488
# Summary: metric mcc value 0.0
# --- Starting trial: run-3
# {'balanced': 1, 'norm_images': 1, 'network': 'CNN', 'act_functions': 'relu', 'num_units': 16, 'dropout': 0.2, 'early_stop': 5, 'optimizer': 'sgd'}
# Model creation
# Model compile
# Fitting training
# Epoch 1/1000
# 35/35 [==============================] - 3s 55ms/step - loss: 0.9134 - tp: 110.0000 - fp: 67.0000 - tn: 108.0000 - fn: 65.0000 - accuracy: 0.6229 - precision: 0.6215 - recall: 0.6286 - auc: 0.6776 - prc: 0.6313 - val_loss: 0.9364 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.6948 - val_prc: 0.6782
# Epoch 2/1000
# 35/35 [==============================] - 1s 42ms/step - loss: 0.4839 - tp: 134.0000 - fp: 37.0000 - tn: 138.0000 - fn: 41.0000 - accuracy: 0.7771 - precision: 0.7836 - recall: 0.7657 - auc: 0.8567 - prc: 0.8592 - val_loss: 1.2067 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5418 - val_prc: 0.5877
# Epoch 3/1000
# 35/35 [==============================] - 1s 42ms/step - loss: 0.3930 - tp: 144.0000 - fp: 30.0000 - tn: 145.0000 - fn: 31.0000 - accuracy: 0.8257 - precision: 0.8276 - recall: 0.8229 - auc: 0.9052 - prc: 0.9063 - val_loss: 1.4124 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5541 - val_prc: 0.5593
# Epoch 4/1000
# 35/35 [==============================] - 1s 42ms/step - loss: 0.3058 - tp: 150.0000 - fp: 21.0000 - tn: 154.0000 - fn: 25.0000 - accuracy: 0.8686 - precision: 0.8772 - recall: 0.8571 - auc: 0.9439 - prc: 0.9473 - val_loss: 1.6111 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.6164 - val_prc: 0.5944
# Epoch 5/1000
# 35/35 [==============================] - 1s 43ms/step - loss: 0.2957 - tp: 154.0000 - fp: 18.0000 - tn: 157.0000 - fn: 21.0000 - accuracy: 0.8886 - precision: 0.8953 - recall: 0.8800 - auc: 0.9476 - prc: 0.9436 - val_loss: 2.4111 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5736 - val_prc: 0.5766
# Epoch 6/1000
# 35/35 [==============================] - 1s 42ms/step - loss: 0.1824 - tp: 167.0000 - fp: 9.0000 - tn: 166.0000 - fn: 8.0000 - accuracy: 0.9514 - precision: 0.9489 - recall: 0.9543 - auc: 0.9811 - prc: 0.9831 - val_loss: 3.0214 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5057 - val_prc: 0.5029
# Evaluation on test
# 17/17 [==============================] - 1s 19ms/step - loss: 4.0259 - tp: 175.0000 - fp: 350.0000 - tn: 0.0000e+00 - fn: 0.0000e+00 - accuracy: 0.3333 - precision: 0.3333 - recall: 1.0000 - auc: 0.5129 - prc: 0.3392
# 132/132 [==============================] - 1s 4ms/step
# Returning metrics results
# Tipo results <class 'list'>
# Summary: metric loss value 4.025865077972412
# Summary: metric tp value 175.0
# Summary: metric fp value 350.0
# Summary: metric tn value 0.0
# Summary: metric fn value 0.0
# Summary: metric accuracy value 0.3333333432674408
# Summary: metric precision value 0.3333333432674408
# Summary: metric recall value 1.0
# Summary: metric auc value 0.5128571391105652
# Summary: metric prc value 0.33923444151878357
# Summary: metric mcc value 0.0
# --- Starting trial: run-4
# {'balanced': 1, 'norm_images': 1, 'network': 'CNN', 'act_functions': 'relu', 'num_units': 16, 'dropout': 0.2, 'early_stop': 7, 'optimizer': 'adam'}
# Model creation
# Model compile
# Fitting training
# Epoch 1/1000
# 35/35 [==============================] - 3s 57ms/step - loss: 0.8383 - tp: 113.0000 - fp: 55.0000 - tn: 120.0000 - fn: 62.0000 - accuracy: 0.6657 - precision: 0.6726 - recall: 0.6457 - auc: 0.7287 - prc: 0.6900 - val_loss: 0.7036 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.7574 - val_prc: 0.6827
# Epoch 2/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.4843 - tp: 133.0000 - fp: 38.0000 - tn: 137.0000 - fn: 42.0000 - accuracy: 0.7714 - precision: 0.7778 - recall: 0.7600 - auc: 0.8551 - prc: 0.8669 - val_loss: 0.8964 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.7533 - val_prc: 0.7414
# Epoch 3/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.3569 - tp: 148.0000 - fp: 24.0000 - tn: 151.0000 - fn: 27.0000 - accuracy: 0.8543 - precision: 0.8605 - recall: 0.8457 - auc: 0.9216 - prc: 0.9282 - val_loss: 1.4833 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.7485 - val_prc: 0.7265
# Epoch 4/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.2240 - tp: 164.0000 - fp: 14.0000 - tn: 161.0000 - fn: 11.0000 - accuracy: 0.9286 - precision: 0.9213 - recall: 0.9371 - auc: 0.9723 - prc: 0.9733 - val_loss: 1.5894 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.8178 - val_prc: 0.8060
# Epoch 5/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.2109 - tp: 161.0000 - fp: 13.0000 - tn: 162.0000 - fn: 14.0000 - accuracy: 0.9229 - precision: 0.9253 - recall: 0.9200 - auc: 0.9723 - prc: 0.9751 - val_loss: 1.6141 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.8049 - val_prc: 0.7729
# Epoch 6/1000
# 35/35 [==============================] - 2s 43ms/step - loss: 0.1311 - tp: 169.0000 - fp: 7.0000 - tn: 168.0000 - fn: 6.0000 - accuracy: 0.9629 - precision: 0.9602 - recall: 0.9657 - auc: 0.9899 - prc: 0.9918 - val_loss: 2.1088 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.7369 - val_prc: 0.7252
# Epoch 7/1000
# 35/35 [==============================] - 2s 43ms/step - loss: 0.0737 - tp: 170.0000 - fp: 3.0000 - tn: 172.0000 - fn: 5.0000 - accuracy: 0.9771 - precision: 0.9827 - recall: 0.9714 - auc: 0.9983 - prc: 0.9984 - val_loss: 2.3966 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.7039 - val_prc: 0.6998
# Epoch 8/1000
# 35/35 [==============================] - 2s 43ms/step - loss: 0.1469 - tp: 167.0000 - fp: 11.0000 - tn: 164.0000 - fn: 8.0000 - accuracy: 0.9457 - precision: 0.9382 - recall: 0.9543 - auc: 0.9861 - prc: 0.9854 - val_loss: 1.0979 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.8216 - val_prc: 0.8032
# Evaluation on test
# 17/17 [==============================] - 1s 20ms/step - loss: 1.4517 - tp: 175.0000 - fp: 350.0000 - tn: 0.0000e+00 - fn: 0.0000e+00 - accuracy: 0.3333 - precision: 0.3333 - recall: 1.0000 - auc: 0.8057 - prc: 0.6946
# 132/132 [==============================] - 1s 3ms/step
# Returning metrics results
# Tipo results <class 'list'>
# Summary: metric loss value 1.4517372846603394
# Summary: metric tp value 175.0
# Summary: metric fp value 350.0
# Summary: metric tn value 0.0
# Summary: metric fn value 0.0
# Summary: metric accuracy value 0.3333333432674408
# Summary: metric precision value 0.3333333432674408
# Summary: metric recall value 1.0
# Summary: metric auc value 0.8057305812835693
# Summary: metric prc value 0.6946167349815369
# Summary: metric mcc value 0.0
# --- Starting trial: run-5
# {'balanced': 1, 'norm_images': 1, 'network': 'CNN', 'act_functions': 'relu', 'num_units': 16, 'dropout': 0.2, 'early_stop': 7, 'optimizer': 'sgd'}
# Model creation
# Model compile
# Fitting training
# Epoch 1/1000
# 35/35 [==============================] - 3s 54ms/step - loss: 0.8075 - tp: 119.0000 - fp: 57.0000 - tn: 118.0000 - fn: 56.0000 - accuracy: 0.6771 - precision: 0.6761 - recall: 0.6800 - auc: 0.7353 - prc: 0.6917 - val_loss: 0.7555 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.6179 - val_prc: 0.5695
# Epoch 2/1000
# 35/35 [==============================] - 1s 42ms/step - loss: 0.4264 - tp: 139.0000 - fp: 33.0000 - tn: 142.0000 - fn: 36.0000 - accuracy: 0.8029 - precision: 0.8081 - recall: 0.7943 - auc: 0.8842 - prc: 0.8950 - val_loss: 0.6826 - val_tp: 155.0000 - val_fp: 119.0000 - val_tn: 56.0000 - val_fn: 20.0000 - val_accuracy: 0.6029 - val_precision: 0.5657 - val_recall: 0.8857 - val_auc: 0.6179 - val_prc: 0.5779
# Epoch 3/1000
# 35/35 [==============================] - 1s 42ms/step - loss: 0.4102 - tp: 142.0000 - fp: 30.0000 - tn: 145.0000 - fn: 33.0000 - accuracy: 0.8200 - precision: 0.8256 - recall: 0.8114 - auc: 0.8940 - prc: 0.8981 - val_loss: 2.8593 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5319 - val_prc: 0.5173
# Epoch 4/1000
# 35/35 [==============================] - 1s 42ms/step - loss: 0.2570 - tp: 159.0000 - fp: 15.0000 - tn: 160.0000 - fn: 16.0000 - accuracy: 0.9114 - precision: 0.9138 - recall: 0.9086 - auc: 0.9616 - prc: 0.9658 - val_loss: 3.6964 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5029 - val_prc: 0.5014
# Epoch 5/1000
# 35/35 [==============================] - 1s 41ms/step - loss: 0.2178 - tp: 157.0000 - fp: 11.0000 - tn: 164.0000 - fn: 18.0000 - accuracy: 0.9171 - precision: 0.9345 - recall: 0.8971 - auc: 0.9751 - prc: 0.9739 - val_loss: 4.6322 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5029 - val_prc: 0.5014
# Epoch 6/1000
# 35/35 [==============================] - 1s 41ms/step - loss: 0.1710 - tp: 164.0000 - fp: 10.0000 - tn: 165.0000 - fn: 11.0000 - accuracy: 0.9400 - precision: 0.9425 - recall: 0.9371 - auc: 0.9825 - prc: 0.9836 - val_loss: 5.7724 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5029 - val_prc: 0.5014
# Epoch 7/1000
# 35/35 [==============================] - 1s 42ms/step - loss: 0.1297 - tp: 168.0000 - fp: 5.0000 - tn: 170.0000 - fn: 7.0000 - accuracy: 0.9657 - precision: 0.9711 - recall: 0.9600 - auc: 0.9898 - prc: 0.9904 - val_loss: 6.3065 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5144 - val_prc: 0.5073
# Epoch 8/1000
# 35/35 [==============================] - 1s 42ms/step - loss: 0.1809 - tp: 165.0000 - fp: 15.0000 - tn: 160.0000 - fn: 10.0000 - accuracy: 0.9286 - precision: 0.9167 - recall: 0.9429 - auc: 0.9804 - prc: 0.9807 - val_loss: 4.5938 - val_tp: 174.0000 - val_fp: 173.0000 - val_tn: 2.0000 - val_fn: 1.0000 - val_accuracy: 0.5029 - val_precision: 0.5014 - val_recall: 0.9943 - val_auc: 0.5223 - val_prc: 0.5119
# Epoch 9/1000
# 35/35 [==============================] - 1s 42ms/step - loss: 0.1634 - tp: 164.0000 - fp: 10.0000 - tn: 165.0000 - fn: 11.0000 - accuracy: 0.9400 - precision: 0.9425 - recall: 0.9371 - auc: 0.9848 - prc: 0.9859 - val_loss: 3.0338 - val_tp: 141.0000 - val_fp: 135.0000 - val_tn: 40.0000 - val_fn: 34.0000 - val_accuracy: 0.5171 - val_precision: 0.5109 - val_recall: 0.8057 - val_auc: 0.5069 - val_prc: 0.5040
# Evaluation on test
# 17/17 [==============================] - 1s 19ms/step - loss: 3.7305 - tp: 147.0000 - fp: 271.0000 - tn: 79.0000 - fn: 28.0000 - accuracy: 0.4305 - precision: 0.3517 - recall: 0.8400 - auc: 0.5493 - prc: 0.3609
# 132/132 [==============================] - 1s 4ms/step
# Returning metrics results
# Tipo results <class 'list'>
# Summary: metric loss value 3.7304999828338623
# Summary: metric tp value 147.0
# Summary: metric fp value 271.0
# Summary: metric tn value 79.0
# Summary: metric fn value 28.0
# Summary: metric accuracy value 0.43047618865966797
# Summary: metric precision value 0.3516746461391449
# Summary: metric recall value 0.8399999737739563
# Summary: metric auc value 0.5493061542510986
# Summary: metric prc value 0.36090999841690063
# Summary: metric mcc value 0.07690114540529913
# --- Starting trial: run-6
# {'balanced': 1, 'norm_images': 1, 'network': 'CNN', 'act_functions': 'relu', 'num_units': 16, 'dropout': 0.2, 'early_stop': 10, 'optimizer': 'adam'}
# Model creation
# Model compile
# Fitting training
# Epoch 1/1000
# 35/35 [==============================] - 3s 60ms/step - loss: 0.8637 - tp: 108.0000 - fp: 53.0000 - tn: 122.0000 - fn: 67.0000 - accuracy: 0.6571 - precision: 0.6708 - recall: 0.6171 - auc: 0.6840 - prc: 0.6470 - val_loss: 0.9005 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 175.0000 - val_fn: 175.0000 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6129 - val_prc: 0.5966
# Epoch 2/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.4932 - tp: 130.0000 - fp: 37.0000 - tn: 138.0000 - fn: 45.0000 - accuracy: 0.7657 - precision: 0.7784 - recall: 0.7429 - auc: 0.8512 - prc: 0.8564 - val_loss: 0.8369 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 175.0000 - val_fn: 175.0000 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6153 - val_prc: 0.6413
# Epoch 3/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.4097 - tp: 144.0000 - fp: 39.0000 - tn: 136.0000 - fn: 31.0000 - accuracy: 0.8000 - precision: 0.7869 - recall: 0.8229 - auc: 0.8925 - prc: 0.8960 - val_loss: 0.8414 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 175.0000 - val_fn: 175.0000 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6194 - val_prc: 0.6036
# Epoch 4/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.3158 - tp: 154.0000 - fp: 23.0000 - tn: 152.0000 - fn: 21.0000 - accuracy: 0.8743 - precision: 0.8701 - recall: 0.8800 - auc: 0.9390 - prc: 0.9339 - val_loss: 0.6632 - val_tp: 85.0000 - val_fp: 37.0000 - val_tn: 138.0000 - val_fn: 90.0000 - val_accuracy: 0.6371 - val_precision: 0.6967 - val_recall: 0.4857 - val_auc: 0.7142 - val_prc: 0.7139
# Epoch 5/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.2895 - tp: 155.0000 - fp: 19.0000 - tn: 156.0000 - fn: 20.0000 - accuracy: 0.8886 - precision: 0.8908 - recall: 0.8857 - auc: 0.9496 - prc: 0.9507 - val_loss: 0.6907 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 175.0000 - val_fn: 172.0000 - val_accuracy: 0.5086 - val_precision: 1.0000 - val_recall: 0.0171 - val_auc: 0.7420 - val_prc: 0.7347
# Epoch 6/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.1587 - tp: 165.0000 - fp: 9.0000 - tn: 166.0000 - fn: 10.0000 - accuracy: 0.9457 - precision: 0.9483 - recall: 0.9429 - auc: 0.9849 - prc: 0.9866 - val_loss: 0.6500 - val_tp: 141.0000 - val_fp: 89.0000 - val_tn: 86.0000 - val_fn: 34.0000 - val_accuracy: 0.6486 - val_precision: 0.6130 - val_recall: 0.8057 - val_auc: 0.7233 - val_prc: 0.7355
# Epoch 7/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.1020 - tp: 168.0000 - fp: 5.0000 - tn: 170.0000 - fn: 7.0000 - accuracy: 0.9657 - precision: 0.9711 - recall: 0.9600 - auc: 0.9952 - prc: 0.9958 - val_loss: 0.6254 - val_tp: 111.0000 - val_fp: 42.0000 - val_tn: 133.0000 - val_fn: 64.0000 - val_accuracy: 0.6971 - val_precision: 0.7255 - val_recall: 0.6343 - val_auc: 0.7720 - val_prc: 0.7563
# Epoch 8/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.1614 - tp: 165.0000 - fp: 11.0000 - tn: 164.0000 - fn: 10.0000 - accuracy: 0.9400 - precision: 0.9375 - recall: 0.9429 - auc: 0.9855 - prc: 0.9861 - val_loss: 0.8816 - val_tp: 175.0000 - val_fp: 174.0000 - val_tn: 1.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.5029 - val_precision: 0.5014 - val_recall: 1.0000 - val_auc: 0.7193 - val_prc: 0.6861
# Epoch 9/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.2308 - tp: 165.0000 - fp: 25.0000 - tn: 150.0000 - fn: 10.0000 - accuracy: 0.9000 - precision: 0.8684 - recall: 0.9429 - auc: 0.9698 - prc: 0.9700 - val_loss: 0.8654 - val_tp: 1.0000 - val_fp: 0.0000e+00 - val_tn: 175.0000 - val_fn: 174.0000 - val_accuracy: 0.5029 - val_precision: 1.0000 - val_recall: 0.0057 - val_auc: 0.6945 - val_prc: 0.7031
# Epoch 10/1000
# 35/35 [==============================] - 2s 45ms/step - loss: 0.0992 - tp: 168.0000 - fp: 4.0000 - tn: 171.0000 - fn: 7.0000 - accuracy: 0.9686 - precision: 0.9767 - recall: 0.9600 - auc: 0.9963 - prc: 0.9963 - val_loss: 0.6094 - val_tp: 66.0000 - val_fp: 18.0000 - val_tn: 157.0000 - val_fn: 109.0000 - val_accuracy: 0.6371 - val_precision: 0.7857 - val_recall: 0.3771 - val_auc: 0.7886 - val_prc: 0.7622
# Epoch 11/1000
# 35/35 [==============================] - 2s 45ms/step - loss: 0.0989 - tp: 167.0000 - fp: 4.0000 - tn: 171.0000 - fn: 8.0000 - accuracy: 0.9657 - precision: 0.9766 - recall: 0.9543 - auc: 0.9942 - prc: 0.9942 - val_loss: 0.9435 - val_tp: 39.0000 - val_fp: 3.0000 - val_tn: 172.0000 - val_fn: 136.0000 - val_accuracy: 0.6029 - val_precision: 0.9286 - val_recall: 0.2229 - val_auc: 0.7851 - val_prc: 0.8051
# Epoch 12/1000
# 35/35 [==============================] - 2s 45ms/step - loss: 0.1287 - tp: 169.0000 - fp: 9.0000 - tn: 166.0000 - fn: 6.0000 - accuracy: 0.9571 - precision: 0.9494 - recall: 0.9657 - auc: 0.9906 - prc: 0.9910 - val_loss: 0.7109 - val_tp: 64.0000 - val_fp: 13.0000 - val_tn: 162.0000 - val_fn: 111.0000 - val_accuracy: 0.6457 - val_precision: 0.8312 - val_recall: 0.3657 - val_auc: 0.7795 - val_prc: 0.7810
# Epoch 13/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.1714 - tp: 163.0000 - fp: 8.0000 - tn: 167.0000 - fn: 12.0000 - accuracy: 0.9429 - precision: 0.9532 - recall: 0.9314 - auc: 0.9807 - prc: 0.9836 - val_loss: 0.9433 - val_tp: 36.0000 - val_fp: 3.0000 - val_tn: 172.0000 - val_fn: 139.0000 - val_accuracy: 0.5943 - val_precision: 0.9231 - val_recall: 0.2057 - val_auc: 0.7921 - val_prc: 0.8014
# Epoch 14/1000
# 35/35 [==============================] - 2s 45ms/step - loss: 0.0726 - tp: 170.0000 - fp: 2.0000 - tn: 173.0000 - fn: 5.0000 - accuracy: 0.9800 - precision: 0.9884 - recall: 0.9714 - auc: 0.9980 - prc: 0.9980 - val_loss: 1.9160 - val_tp: 175.0000 - val_fp: 166.0000 - val_tn: 9.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.5257 - val_precision: 0.5132 - val_recall: 1.0000 - val_auc: 0.7777 - val_prc: 0.7114
# Epoch 15/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.1129 - tp: 167.0000 - fp: 7.0000 - tn: 168.0000 - fn: 8.0000 - accuracy: 0.9571 - precision: 0.9598 - recall: 0.9543 - auc: 0.9906 - prc: 0.9927 - val_loss: 1.0301 - val_tp: 172.0000 - val_fp: 132.0000 - val_tn: 43.0000 - val_fn: 3.0000 - val_accuracy: 0.6143 - val_precision: 0.5658 - val_recall: 0.9829 - val_auc: 0.8555 - val_prc: 0.8213
# Epoch 16/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.0474 - tp: 171.0000 - fp: 1.0000 - tn: 174.0000 - fn: 4.0000 - accuracy: 0.9857 - precision: 0.9942 - recall: 0.9771 - auc: 0.9995 - prc: 0.9995 - val_loss: 0.8184 - val_tp: 166.0000 - val_fp: 108.0000 - val_tn: 67.0000 - val_fn: 9.0000 - val_accuracy: 0.6657 - val_precision: 0.6058 - val_recall: 0.9486 - val_auc: 0.8034 - val_prc: 0.7917
# Epoch 17/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.0702 - tp: 167.0000 - fp: 2.0000 - tn: 173.0000 - fn: 8.0000 - accuracy: 0.9714 - precision: 0.9882 - recall: 0.9543 - auc: 0.9974 - prc: 0.9976 - val_loss: 0.8248 - val_tp: 165.0000 - val_fp: 96.0000 - val_tn: 79.0000 - val_fn: 10.0000 - val_accuracy: 0.6971 - val_precision: 0.6322 - val_recall: 0.9429 - val_auc: 0.8432 - val_prc: 0.8153
# Epoch 18/1000
# 35/35 [==============================] - 2s 45ms/step - loss: 0.0429 - tp: 173.0000 - fp: 3.0000 - tn: 172.0000 - fn: 2.0000 - accuracy: 0.9857 - precision: 0.9830 - recall: 0.9886 - auc: 0.9990 - prc: 0.9990 - val_loss: 0.5842 - val_tp: 146.0000 - val_fp: 51.0000 - val_tn: 124.0000 - val_fn: 29.0000 - val_accuracy: 0.7714 - val_precision: 0.7411 - val_recall: 0.8343 - val_auc: 0.8350 - val_prc: 0.8080
# Epoch 19/1000
# 35/35 [==============================] - 2s 45ms/step - loss: 0.0391 - tp: 175.0000 - fp: 4.0000 - tn: 171.0000 - fn: 0.0000e+00 - accuracy: 0.9886 - precision: 0.9777 - recall: 1.0000 - auc: 0.9998 - prc: 0.9998 - val_loss: 0.9115 - val_tp: 80.0000 - val_fp: 14.0000 - val_tn: 161.0000 - val_fn: 95.0000 - val_accuracy: 0.6886 - val_precision: 0.8511 - val_recall: 0.4571 - val_auc: 0.8432 - val_prc: 0.8228
# Epoch 20/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.0182 - tp: 174.0000 - fp: 0.0000e+00 - tn: 175.0000 - fn: 1.0000 - accuracy: 0.9971 - precision: 1.0000 - recall: 0.9943 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.6481 - val_tp: 142.0000 - val_fp: 44.0000 - val_tn: 131.0000 - val_fn: 33.0000 - val_accuracy: 0.7800 - val_precision: 0.7634 - val_recall: 0.8114 - val_auc: 0.8402 - val_prc: 0.8211
# Epoch 21/1000
# 35/35 [==============================] - 2s 45ms/step - loss: 0.0419 - tp: 172.0000 - fp: 1.0000 - tn: 174.0000 - fn: 3.0000 - accuracy: 0.9886 - precision: 0.9942 - recall: 0.9829 - auc: 0.9988 - prc: 0.9989 - val_loss: 0.7167 - val_tp: 149.0000 - val_fp: 67.0000 - val_tn: 108.0000 - val_fn: 26.0000 - val_accuracy: 0.7343 - val_precision: 0.6898 - val_recall: 0.8514 - val_auc: 0.8177 - val_prc: 0.7846
# Epoch 22/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.0335 - tp: 172.0000 - fp: 3.0000 - tn: 172.0000 - fn: 3.0000 - accuracy: 0.9829 - precision: 0.9829 - recall: 0.9829 - auc: 0.9997 - prc: 0.9997 - val_loss: 0.7686 - val_tp: 141.0000 - val_fp: 46.0000 - val_tn: 129.0000 - val_fn: 34.0000 - val_accuracy: 0.7714 - val_precision: 0.7540 - val_recall: 0.8057 - val_auc: 0.8468 - val_prc: 0.8222
# Epoch 23/1000
# 35/35 [==============================] - 2s 45ms/step - loss: 0.0514 - tp: 170.0000 - fp: 3.0000 - tn: 172.0000 - fn: 5.0000 - accuracy: 0.9771 - precision: 0.9827 - recall: 0.9714 - auc: 0.9987 - prc: 0.9987 - val_loss: 0.7797 - val_tp: 98.0000 - val_fp: 26.0000 - val_tn: 149.0000 - val_fn: 77.0000 - val_accuracy: 0.7057 - val_precision: 0.7903 - val_recall: 0.5600 - val_auc: 0.8211 - val_prc: 0.8085
# Epoch 24/1000
# 35/35 [==============================] - 2s 45ms/step - loss: 0.0391 - tp: 172.0000 - fp: 2.0000 - tn: 173.0000 - fn: 3.0000 - accuracy: 0.9857 - precision: 0.9885 - recall: 0.9829 - auc: 0.9995 - prc: 0.9995 - val_loss: 1.0965 - val_tp: 164.0000 - val_fp: 89.0000 - val_tn: 86.0000 - val_fn: 11.0000 - val_accuracy: 0.7143 - val_precision: 0.6482 - val_recall: 0.9371 - val_auc: 0.8351 - val_prc: 0.7881
# Epoch 25/1000
# 35/35 [==============================] - 2s 45ms/step - loss: 0.0209 - tp: 175.0000 - fp: 1.0000 - tn: 174.0000 - fn: 0.0000e+00 - accuracy: 0.9971 - precision: 0.9943 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.7990 - val_tp: 111.0000 - val_fp: 32.0000 - val_tn: 143.0000 - val_fn: 64.0000 - val_accuracy: 0.7257 - val_precision: 0.7762 - val_recall: 0.6343 - val_auc: 0.8264 - val_prc: 0.8166
# Epoch 26/1000
# 35/35 [==============================] - 2s 45ms/step - loss: 0.0348 - tp: 173.0000 - fp: 1.0000 - tn: 174.0000 - fn: 2.0000 - accuracy: 0.9914 - precision: 0.9943 - recall: 0.9886 - auc: 0.9963 - prc: 0.9977 - val_loss: 1.2419 - val_tp: 159.0000 - val_fp: 95.0000 - val_tn: 80.0000 - val_fn: 16.0000 - val_accuracy: 0.6829 - val_precision: 0.6260 - val_recall: 0.9086 - val_auc: 0.8016 - val_prc: 0.7565
# Epoch 27/1000
# 35/35 [==============================] - 2s 45ms/step - loss: 0.0321 - tp: 174.0000 - fp: 4.0000 - tn: 171.0000 - fn: 1.0000 - accuracy: 0.9857 - precision: 0.9775 - recall: 0.9943 - auc: 0.9998 - prc: 0.9998 - val_loss: 0.9139 - val_tp: 89.0000 - val_fp: 18.0000 - val_tn: 157.0000 - val_fn: 86.0000 - val_accuracy: 0.7029 - val_precision: 0.8318 - val_recall: 0.5086 - val_auc: 0.8342 - val_prc: 0.8278
# Epoch 28/1000
# 35/35 [==============================] - 2s 45ms/step - loss: 0.0195 - tp: 174.0000 - fp: 1.0000 - tn: 174.0000 - fn: 1.0000 - accuracy: 0.9943 - precision: 0.9943 - recall: 0.9943 - auc: 1.0000 - prc: 1.0000 - val_loss: 1.3181 - val_tp: 164.0000 - val_fp: 106.0000 - val_tn: 69.0000 - val_fn: 11.0000 - val_accuracy: 0.6657 - val_precision: 0.6074 - val_recall: 0.9371 - val_auc: 0.8021 - val_prc: 0.7460
# Evaluation on test
# 17/17 [==============================] - 1s 19ms/step - loss: 1.6683 - tp: 157.0000 - fp: 182.0000 - tn: 168.0000 - fn: 18.0000 - accuracy: 0.6190 - precision: 0.4631 - recall: 0.8971 - auc: 0.7797 - prc: 0.5811
# 132/132 [==============================] - 1s 4ms/step
# Returning metrics results
# Tipo results <class 'list'>
# Summary: metric loss value 1.6682692766189575
# Summary: metric tp value 157.0
# Summary: metric fp value 182.0
# Summary: metric tn value 168.0
# Summary: metric fn value 18.0
# Summary: metric accuracy value 0.6190476417541504
# Summary: metric precision value 0.4631268382072449
# Summary: metric recall value 0.8971428275108337
# Summary: metric auc value 0.7797224521636963
# Summary: metric prc value 0.5811258554458618
# Summary: metric mcc value 0.3717086025156371
# --- Starting trial: run-7
# {'balanced': 1, 'norm_images': 1, 'network': 'CNN', 'act_functions': 'relu', 'num_units': 16, 'dropout': 0.2, 'early_stop': 10, 'optimizer': 'sgd'}
# Model creation
# Model compile
# Fitting training
# Epoch 1/1000
# 35/35 [==============================] - 3s 60ms/step - loss: 0.8035 - tp: 114.0000 - fp: 63.0000 - tn: 112.0000 - fn: 61.0000 - accuracy: 0.6457 - precision: 0.6441 - recall: 0.6514 - auc: 0.7194 - prc: 0.6954 - val_loss: 0.9791 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.6345 - val_prc: 0.6252
# Epoch 2/1000
# 35/35 [==============================] - 1s 43ms/step - loss: 0.4484 - tp: 138.0000 - fp: 37.0000 - tn: 138.0000 - fn: 37.0000 - accuracy: 0.7886 - precision: 0.7886 - recall: 0.7886 - auc: 0.8727 - prc: 0.8761 - val_loss: 1.3373 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5986 - val_prc: 0.5923
# Epoch 3/1000
# 35/35 [==============================] - 1s 42ms/step - loss: 0.3418 - tp: 144.0000 - fp: 27.0000 - tn: 148.0000 - fn: 31.0000 - accuracy: 0.8343 - precision: 0.8421 - recall: 0.8229 - auc: 0.9274 - prc: 0.9302 - val_loss: 1.7300 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5536 - val_prc: 0.5381
# Epoch 4/1000
# 35/35 [==============================] - 2s 43ms/step - loss: 0.2382 - tp: 156.0000 - fp: 14.0000 - tn: 161.0000 - fn: 19.0000 - accuracy: 0.9057 - precision: 0.9176 - recall: 0.8914 - auc: 0.9679 - prc: 0.9709 - val_loss: 1.9927 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5786 - val_prc: 0.5786
# Epoch 5/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.2166 - tp: 160.0000 - fp: 12.0000 - tn: 163.0000 - fn: 15.0000 - accuracy: 0.9229 - precision: 0.9302 - recall: 0.9143 - auc: 0.9742 - prc: 0.9736 - val_loss: 2.5044 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5602 - val_prc: 0.5399
# Epoch 6/1000
# 35/35 [==============================] - 1s 43ms/step - loss: 0.1443 - tp: 164.0000 - fp: 7.0000 - tn: 168.0000 - fn: 11.0000 - accuracy: 0.9486 - precision: 0.9591 - recall: 0.9371 - auc: 0.9885 - prc: 0.9894 - val_loss: 2.4000 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5490 - val_prc: 0.5358
# Epoch 7/1000
# 35/35 [==============================] - 2s 43ms/step - loss: 0.1049 - tp: 170.0000 - fp: 4.0000 - tn: 171.0000 - fn: 5.0000 - accuracy: 0.9743 - precision: 0.9770 - recall: 0.9714 - auc: 0.9925 - prc: 0.9948 - val_loss: 2.5949 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5689 - val_prc: 0.5449
# Epoch 8/1000
# 35/35 [==============================] - 2s 44ms/step - loss: 0.1259 - tp: 167.0000 - fp: 11.0000 - tn: 164.0000 - fn: 8.0000 - accuracy: 0.9457 - precision: 0.9382 - recall: 0.9543 - auc: 0.9923 - prc: 0.9923 - val_loss: 2.3506 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.6871 - val_prc: 0.6812
# Epoch 9/1000
# 35/35 [==============================] - 1s 43ms/step - loss: 0.1673 - tp: 167.0000 - fp: 16.0000 - tn: 159.0000 - fn: 8.0000 - accuracy: 0.9314 - precision: 0.9126 - recall: 0.9543 - auc: 0.9825 - prc: 0.9832 - val_loss: 2.6240 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.6850 - val_prc: 0.6352
# Epoch 10/1000
# 35/35 [==============================] - 1s 43ms/step - loss: 0.0787 - tp: 171.0000 - fp: 4.0000 - tn: 171.0000 - fn: 4.0000 - accuracy: 0.9771 - precision: 0.9771 - recall: 0.9771 - auc: 0.9976 - prc: 0.9976 - val_loss: 3.1943 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.5114 - val_prc: 0.5058
# Epoch 11/1000
# 35/35 [==============================] - 2s 43ms/step - loss: 0.0799 - tp: 170.0000 - fp: 3.0000 - tn: 172.0000 - fn: 5.0000 - accuracy: 0.9771 - precision: 0.9827 - recall: 0.9714 - auc: 0.9976 - prc: 0.9976 - val_loss: 2.8354 - val_tp: 175.0000 - val_fp: 175.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.6532 - val_prc: 0.5922
# Evaluation on test
# 17/17 [==============================] - 1s 20ms/step - loss: 3.6980 - tp: 175.0000 - fp: 350.0000 - tn: 0.0000e+00 - fn: 0.0000e+00 - accuracy: 0.3333 - precision: 0.3333 - recall: 1.0000 - auc: 0.6559 - prc: 0.4246
# 132/132 [==============================] - 1s 3ms/step
# Returning metrics results
# Tipo results <class 'list'>
# Summary: metric loss value 3.697969913482666
# Summary: metric tp value 175.0
# Summary: metric fp value 350.0
# Summary: metric tn value 0.0
# Summary: metric fn value 0.0
# Summary: metric accuracy value 0.3333333432674408
# Summary: metric precision value 0.3333333432674408
# Summary: metric recall value 1.0
# Summary: metric auc value 0.6559183597564697
# Summary: metric prc value 0.4245789349079132
# Summary: metric mcc value 0.0
# --- Starting trial: run-8
# {'balanced': 1, 'norm_images': 1, 'network': 'CNN', 'act_functions': 'relu', 'num_units': 16, 'dropout': 0.5, 'early_stop': 3, 'optimizer': 'adam'}
# Model creation
# Model compile
# Fitting training
# Epoch 1/1000
# 35/35 [==============================] - 3s 57ms/step - loss: 0.8164 - tp: 121.0000 - fp: 62.0000 - tn: 113.0000 - fn: 54.0000 - accuracy: 0.6686 - precision: 0.6612 - recall: 0.6914 - auc: 0.7129 - prc: 0.6504 - val_loss: 1.1784 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 175.0000 - val_fn: 175.0000 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5615 - val_prc: 0.5773
# Epoch 2/1000
# 35/35 [==============================] - 2s 45ms/step - loss: 0.4726 - tp: 133.0000 - fp: 36.0000 - tn: 139.0000 - fn: 42.0000 - accuracy: 0.7771 - precision: 0.7870 - recall: 0.7600 - auc: 0.8630 - prc: 0.8795 - val_loss: 0.6914 - val_tp: 6.0000 - val_fp: 0.0000e+00 - val_tn: 175.0000 - val_fn: 169.0000 - val_accuracy: 0.5171 - val_precision: 1.0000 - val_recall: 0.0343 - val_auc: 0.7467 - val_prc: 0.7664
# Epoch 3/1000
# 35/35 [==============================] - 2s 45ms/step - loss: 0.3971 - tp: 136.0000 - fp: 31.0000 - tn: 144.0000 - fn: 39.0000 - accuracy: 0.8000 - precision: 0.8144 - recall: 0.7771 - auc: 0.9027 - prc: 0.9091 - val_loss: 0.7223 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 175.0000 - val_fn: 175.0000 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7666 - val_prc: 0.7571
# Epoch 4/1000
# 35/35 [==============================] - 2s 45ms/step - loss: 0.2918 - tp: 152.0000 - fp: 20.0000 - tn: 155.0000 - fn: 23.0000 - accuracy: 0.8771 - precision: 0.8837 - recall: 0.8686 - auc: 0.9484 - prc: 0.9454 - val_loss: 0.7168 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 175.0000 - val_fn: 175.0000 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8189 - val_prc: 0.8065
# Epoch 5/1000
# 35/35 [==============================] - 2s 45ms/step - loss: 0.3067 - tp: 148.0000 - fp: 26.0000 - tn: 149.0000 - fn: 27.0000 - accuracy: 0.8486 - precision: 0.8506 - recall: 0.8457 - auc: 0.9429 - prc: 0.9488 - val_loss: 0.7633 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 175.0000 - val_fn: 175.0000 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7640 - val_prc: 0.7594
# Evaluation on test
# 17/17 [==============================] - 1s 19ms/step - loss: 0.5928 - tp: 1.0000 - fp: 0.0000e+00 - tn: 350.0000 - fn: 174.0000 - accuracy: 0.6686 - precision: 1.0000 - recall: 0.0057 - auc: 0.7740 - prc: 0.6793
# 132/132 [==============================] - 1s 4ms/step
# Returning metrics results
# Tipo results <class 'list'>
# Summary: metric loss value 0.5928468704223633
# Summary: metric tp value 1.0
# Summary: metric fp value 0.0
# Summary: metric tn value 350.0
# Summary: metric fn value 174.0
# Summary: metric accuracy value 0.668571412563324
# Summary: metric precision value 1.0
# Summary: metric recall value 0.0057142856530845165
# Summary: metric auc value 0.7739918828010559
# Summary: metric prc value 0.6793298721313477
# Summary: metric mcc value 0.06178020632152155
# --- Starting trial: run-9
# {'balanced': 1, 'norm_images': 1, 'network': 'CNN', 'act_functions': 'relu', 'num_units': 16, 'dropout': 0.5, 'early_stop': 3, 'optimizer': 'sgd'}
# Model creation
# Model compile
# Fitting training
# Epoch 1/1000
# ...
# 2022-10-29 23:28:01.787700: I tensorflow/core/common_runtime/bfc_allocator.cc:1089] InUse at 7fbdfcc13e00 of size 256 next 238
# 2022-10-29 23:28:01.787701: I tensorflow/core/common_runtime/bfc_allocator.cc:1089] InUse at 7fbdfcc13f00 of size 2816 next 382
# 2022-10-29 23:28:01.787704: I tensorflow/core/common_runtime/bfc_allocator.cc:1089] InUse at 7fbdfcc14a00 of size 445625856 next 18446744073709551615
# 2022-10-29 23:28:01.787705: I tensorflow/core/common_runtime/bfc_allocator.cc:1094]      Summary of in-use Chunks by size:
# 2022-10-29 23:28:01.787709: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 239 Chunks of size 256 totalling 59.8KiB
# 2022-10-29 23:28:01.787711: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 34 Chunks of size 512 totalling 17.0KiB
# 2022-10-29 23:28:01.787713: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 3 Chunks of size 768 totalling 2.2KiB
# 2022-10-29 23:28:01.787715: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 40 Chunks of size 1024 totalling 40.0KiB
# 2022-10-29 23:28:01.787718: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 6 Chunks of size 1280 totalling 7.5KiB
# 2022-10-29 23:28:01.787720: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 2 Chunks of size 1536 totalling 3.0KiB
# 2022-10-29 23:28:01.787722: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 8 Chunks of size 1792 totalling 14.0KiB
# 2022-10-29 23:28:01.787724: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 6 Chunks of size 2816 totalling 16.5KiB
# 2022-10-29 23:28:01.787726: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 2 Chunks of size 4352 totalling 8.5KiB
# 2022-10-29 23:28:01.787728: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 1 Chunks of size 5120 totalling 5.0KiB
# 2022-10-29 23:28:01.787730: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 3 Chunks of size 9728 totalling 28.5KiB
# 2022-10-29 23:28:01.787732: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 1 Chunks of size 11264 totalling 11.0KiB
# 2022-10-29 23:28:01.787734: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 1 Chunks of size 13312 totalling 13.0KiB
# 2022-10-29 23:28:01.787736: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 1 Chunks of size 17920 totalling 17.5KiB
# 2022-10-29 23:28:01.787738: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 3 Chunks of size 73728 totalling 216.0KiB
# 2022-10-29 23:28:01.787741: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 1 Chunks of size 95488 totalling 93.2KiB
# 2022-10-29 23:28:01.787743: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 1 Chunks of size 100608 totalling 98.2KiB
# 2022-10-29 23:28:01.787745: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 4 Chunks of size 294912 totalling 1.12MiB
# 2022-10-29 23:28:01.787747: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 1 Chunks of size 516096 totalling 504.0KiB
# 2022-10-29 23:28:01.787749: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 1 Chunks of size 25165824 totalling 24.00MiB
# 2022-10-29 23:28:01.787751: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 1 Chunks of size 40435200 totalling 38.56MiB
# 2022-10-29 23:28:01.787754: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 3 Chunks of size 125960192 totalling 360.38MiB
# 2022-10-29 23:28:01.787756: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 1 Chunks of size 178579968 totalling 170.31MiB
# 2022-10-29 23:28:01.787758: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 1 Chunks of size 251330560 totalling 239.69MiB
# 2022-10-29 23:28:01.787760: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 1 Chunks of size 260112384 totalling 248.06MiB
# 2022-10-29 23:28:01.787762: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 3 Chunks of size 275251200 totalling 787.50MiB
# 2022-10-29 23:28:01.787764: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 1 Chunks of size 279260160 totalling 266.32MiB
# 2022-10-29 23:28:01.787767: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 1 Chunks of size 314683136 totalling 300.10MiB
# 2022-10-29 23:28:01.787770: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 1 Chunks of size 314706432 totalling 300.13MiB
# 2022-10-29 23:28:01.787772: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 2 Chunks of size 412876800 totalling 787.50MiB
# 2022-10-29 23:28:01.787774: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] 1 Chunks of size 445625856 totalling 424.98MiB
# 2022-10-29 23:28:01.787776: I tensorflow/core/common_runtime/bfc_allocator.cc:1101] Sum Total of in-use chunks: 3.86GiB
# 2022-10-29 23:28:01.787778: I tensorflow/core/common_runtime/bfc_allocator.cc:1103] total_region_allocated_bytes_: 4317052928 memory_limit_: 4317052928 available bytes: 0 curr_region_allocation_bytes_: 8634105856
# 2022-10-29 23:28:01.787785: I tensorflow/core/common_runtime/bfc_allocator.cc:1109] Stats:
# Limit:                      4317052928
# InUse:                      4141649664
# MaxInUse:                   4141649920
# NumAllocs:                     1146578
# MaxAllocSize:               1380220928
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-10-29 23:28:01.787810: W tensorflow/core/common_runtime/bfc_allocator.cc:491] ************************x**************************___****xx****************************************
# 2022-10-29 23:28:01.787829: W tensorflow/core/framework/op_kernel.cc:1780] OP_REQUIRES failed at conv_ops_fused_impl.h:541 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[32,32,252,252] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Input In [6], in <cell line: 13>()
#      30 print('--- Starting trial: %s' % run_name)
#      31 print({h.name: hparams[h] for h in hparams})
# ---> 32 run('logs/hparam_tuning/' + run_name, hparams, data)
#      33 session_num += 1
#
# Input In [5], in run(run_dir, hparams, data)
#      29 with tf.summary.create_file_writer(run_dir).as_default():
#      30     hp.hparams(hparams)  # record the values used in this trial
# ---> 31     results = train_test_model(hparams, METRICS, data)
#      32     print("Tipo results", type(results))
#      34     for name, metric in zip(METRICS_NAMES, results):
#
# Input In [4], in train_test_model(hparams, METRICS, data)
#      57 # Evaluation on test
#      58 print("Evaluation on test")
# ---> 59 results = model.evaluate(X_test, y_test)
#      61 y_pred = (model.predict(X_test, batch_size=4)>0.5).reshape(1,-1)[0].astype(int)
#      64 results.append(matthews_corrcoef(y_test, y_pred))
#
# File ~/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'sequential/conv2d/Relu' defined at (most recent call last):
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/ipykernel_launcher.py", line 16, in <module>
#       app.launch_new_instance()
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/traitlets/config/application.py", line 846, in launch_instance
#       app.start()
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 677, in start
#       self.io_loop.start()
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#       self._run_once()
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#       handle._run()
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_queue
#       await self.process_one()
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 460, in process_one
#       await dispatch(*args)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 367, in dispatch_shell
#       await result
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 662, in execute_request
#       reply_content = await reply_content
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 360, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2881, in run_cell
#       result = self._run_cell(
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2936, in _run_cell
#       return runner(coro)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3135, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3338, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3398, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_274519/946586298.py", line 32, in <cell line: 13>
#       run('logs/hparam_tuning/' + run_name, hparams, data)
#     File "/tmp/ipykernel_274519/2068377871.py", line 31, in run
#       results = train_test_model(hparams, METRICS, data)
#     File "/tmp/ipykernel_274519/335866857.py", line 59, in train_test_model
#       results = model.evaluate(X_test, y_test)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/engine/training.py", line 1947, in evaluate
#       tmp_logs = self.test_function(iterator)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/engine/training.py", line 1727, in test_function
#       return step_function(self, iterator)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/engine/training.py", line 1713, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/engine/training.py", line 1701, in run_step
#       outputs = model.test_step(data)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/engine/training.py", line 1665, in test_step
#       y_pred = self(x, training=False)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/engine/training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/engine/base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/engine/sequential.py", line 410, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/engine/functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/engine/functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/engine/base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/layers/convolutional/base_conv.py", line 314, in call
#       return self.activation(outputs)
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/activations.py", line 317, in relu
#       return backend.relu(
#     File "/home/polivares/anaconda3/envs/partial_discharge/lib/python3.10/site-packages/keras/backend.py", line 5366, in relu
#       x = tf.nn.relu(x)
# Node: 'sequential/conv2d/Relu'
# OOM when allocating tensor with shape[32,32,252,252] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node sequential/conv2d/Relu}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_test_function_136845]
